# %%
import pandas as pd
import matplotlib.pyplot as plt
import scipy.cluster.hierarchy as sch
from sklearn.cluster import AgglomerativeClustering
from sklearn.preprocessing import StandardScaler

# Load the dataset
df = pd.read_csv('/content/Mall_Customers.csv')

# Display the first few rows
df.head()
# Out:
#    CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
X = df.iloc[:, [3, 4]]

# Initializing the StandardScaler
scaler = StandardScaler()

# Fitting and transforming the feature matrix X
X_scaled = scaler.fit_transform(X)

print('Feature matrix X and scaled matrix X_scaled created successfully.')
print(f'Shape of X_scaled: {X_scaled.shape}')
# Out:
# Feature matrix X and scaled matrix X_scaled created successfully.
# Shape of X_scaled: (200, 2)

# %% [markdown]
# **Reasoning**:
# The previous step failed because the `df` DataFrame was not defined when the code was executed. To fix this, I will add the line to reload the `df` DataFrame at the beginning of the cell to ensure it is available for processing.

# %%
# Load the dataset (to ensure 'df' is defined for this step)
df = pd.read_csv('/content/Mall_Customers.csv')

# Extracting the features 'Annual Income (k$)' and 'Spending Score (1-100)'
X = df.iloc[:, [3, 4]]

# Initializing the StandardScaler
scaler = StandardScaler()

# Fitting and transforming the feature matrix X
X_scaled = scaler.fit_transform(X)

print('Feature matrix X and scaled matrix X_scaled created successfully.')
print(f'Shape of X_scaled: {X_scaled.shape}')
# Out:
# Feature matrix X and scaled matrix X_scaled created successfully.
# Shape of X_scaled: (200, 2)

# %%
import scipy.cluster.hierarchy as sch
import matplotlib.pyplot as plt

# Create the linkage matrix using the Ward method
linkage_matrix = sch.linkage(X_scaled, method='ward')

# Create the dendrogram plot
plt.figure(figsize=(15, 8))
sch.dendrogram(linkage_matrix)

# Adding titles and labels
plt.title('Dendrogram for Customer Segments')
plt.xlabel('Customers')
plt.ylabel('Euclidean distances')

# Display the plot
plt.show()

# %%
# 5. Visualize the clusters
plt.figure(figsize=(10, 6))

# Plotting each cluster
for i in range(5):
    plt.scatter(X_scaled[y_hc == i, 0], X_scaled[y_hc == i, 1], s=100, label=f'Cluster {i}')

plt.title('Clusters of Customers (Agglomerative Clustering)')
plt.xlabel('Annual Income (scaled)')
plt.ylabel('Spending Score (scaled)')
plt.legend()
plt.show()
